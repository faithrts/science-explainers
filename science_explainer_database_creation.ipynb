# %% [markdown]
# <a href="https://colab.research.google.com/github/faithrts/Science_Explainers/blob/main/science_explainer_database_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
### importing libraries

# basic libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# libraries for web scraping
from bs4 import BeautifulSoup
import requests
import re
import codecs

# sklearn libraries for ML
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
### making a folder for the txt files

# !mkdir txt_files

# %% [markdown]
# # Importing article URLs

# %%
### cloning git repo and saving csv file of URLs into dataframe

# !git clone https://github.com/faithrts/Science_Explainers
# Out:
# Cloning into 'Science_Explainers'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 112 (delta 1), reused 0 (delta 0), pack-reused 106
# Receiving objects: 100% (112/112), 314.92 KiB | 2.23 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
### saving csv file of URLs into dataframe

urls_df = pd.read_csv('Science_Explainers/article_urls.csv')

# replaces all NaN instances with 0
urls_df = urls_df.fillna('')

# %%
urls_df
# Out:
#                                              ATLANTIC  \
# 0   https://www.theatlantic.com/science/archive/20...
# 1   https://www.theatlantic.com/science/archive/20...
# 2   https://www.theatlantic.com/science/archive/20...
# 3   https://www.theatlantic.com/science/archive/20...
# 4   https://www.theatlantic.com/science/archive/20...
# 5   https://www.theatlantic.com/science/archive/20...
# 6   https://www.theatlantic.com/science/archive/20...
# 7   https://www.theatlantic.com/science/archive/20...
# 8   https://www.theatlantic.com/science/archive/20...
# 9   https://www.theatlantic.com/science/archive/20...
# 10  https://www.theatlantic.com/science/archive/20...
# 11  https://www.theatlantic.com/science/archive/20...
# 12  https://www.theatlantic.com/science/archive/20...
# 13  https://www.theatlantic.com/science/archive/20...
# 14  https://www.theatlantic.com/science/archive/20...
# 15  https://www.theatlantic.com/science/archive/20...
# 16  https://www.theatlantic.com/science/archive/20...
# 17  https://www.theatlantic.com/health/archive/202...
# 18  https://www.theatlantic.com/science/archive/20...
# 19
#
#                                                   CBC  \
# 0   https://www.cbc.ca/radio/quirks/dec-3-growling...
# 1   https://www.cbc.ca/radio/quirks/black-holes-je...
# 2   https://www.cbc.ca/radio/quirks/europe-s-juice...
# 3   https://www.cbc.ca/radio/quirks/artificial-int...
# 4   https://www.cbc.ca/radio/quirks/habitable-plan...
# 5   https://www.cbc.ca/radio/quirks/koala-book-dan...
# 6   https://www.cbc.ca/radio/quirks/research-earli...
# 7   https://www.cbc.ca/radio/quirks/feb-25-giraffe...
# 8   https://www.cbc.ca/radio/quirks/feb-18-super-s...
# 9   https://www.cbc.ca/news/science/edna-vacuum-ai...
# 10  https://www.cbc.ca/news/canada/windsor/bird-mi...
# 11  https://www.cbc.ca/news/canada/kitchener-water...
# 12  https://www.cbc.ca/news/canada/british-columbi...
# 13  https://www.cbc.ca/news/canada/british-columbi...
# 14  https://www.cbc.ca/news/canada/newfoundland-la...
# 15  https://www.cbc.ca/news/canada/invasive-turtle...
# 16  https://www.cbc.ca/news/science/what-on-earth-...
# 17  https://www.cbc.ca/news/science/what-on-earth-...
# 18  https://www.cbc.ca/news/science/what-on-earth-...
# 19
#
#                                                   CNN  \
# 14  https://www.npr.org/sections/health-shots/2023...
# 15  https://www.npr.org/sections/health-shots/2023...
# 16  https://www.npr.org/2023/04/12/1169531195/swim...
# 17  https://www.npr.org/2023/04/12/1169266941/glob...
# 18  https://www.npr.org/2023/03/28/1166422313/warm...
# 19  https://www.npr.org/2023/03/08/1161902940/inte...
#
#                                                   NYT  \
# 0   https://www.nytimes.com/2023/05/01/science/ai-...
# 1   https://www.nytimes.com/2023/04/28/science/fro...
# 2   https://www.nytimes.com/2023/04/27/science/qua...
# 3   https://www.nytimes.com/2023/04/25/science/gol...
# 4   https://www.nytimes.com/2023/04/27/science/mot...
# 5   https://www.nytimes.com/2023/04/28/health/brea...
# 6   https://www.nytimes.com/2023/04/27/science/hum...
# 7   https://www.nytimes.com/2023/04/20/science/sal...
# 8   https://www.nytimes.com/2023/04/18/health/covi...
# 9   https://www.nytimes.com/2023/04/13/climate/fla...
# 10  https://www.nytimes.com/2023/04/13/science/ast...
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 19
#
#                                               REUTERS
# 0   https://www.reuters.com/technology/space/study...
# 1   https://www.reuters.com/lifestyle/oldest-known...
# 2   https://www.reuters.com/lifestyle/science/toot...
# 3   https://www.reuters.com/technology/space/new-i...
# 4   https://www.reuters.com/science/ambitious-geno...
# 5   https://www.reuters.com/lifestyle/science/you-...
# 6   https://www.reuters.com/science/good-dog-with-...
# 7   https://www.reuters.com/world/middle-east/dish...
# 8   https://www.reuters.com/world/europe/pendant-i...
# 9   https://www.reuters.com/science/china-approves...
# 10  https://www.reuters.com/technology/space/with-...
# 11  https://www.reuters.com/lifestyle/science/chin...
# 12  https://www.reuters.com/lifestyle/science/scie...
# 13  https://www.reuters.com/lifestyle/science/smal...
# 14  https://www.reuters.com/lifestyle/science/stud...
# 15  https://www.reuters.com/lifestyle/science/intr...
# 16  https://www.reuters.com/lifestyle/science/scie...
# 17  https://www.reuters.com/lifestyle/science/lock...
# 18  https://www.reuters.com/lifestyle/science/seco...
# 19

# %% [markdown]
# # Webscraping helper functions

# %%
def create_txt_file(soup, filename):

  # creates a new file
  cur_file = open('txt_files/' + filename, 'w+')

  # iterates through each passage in the article by finding <p> tags
  for passage in soup.findAll('p'):

    # extracts the text
    text = passage.get_text()

    # fixing spacing
    text = text.replace(u'\xa0', u' ')
    text = text.replace(u'  ', u' ')

    # adding a newline before the next passage
    text += '\n'

    # writing the text to the current file
    cur_file.write(text)

  cur_file.close()

# %%
def source_finder(url):
  # testing default source finder
  source = re.search('(?<=https:\/\/www\.)(.*?)(=?\.)', url).group(1)

  # if no source found, tests another link format
  if len(source) == 0:
    source = re.search('(?<=https:\/\/)(.*?)(=?\.)', url).group(1)

  return source

# %%
def title_cleaner(title):
  # removes punctuation
  title = re.sub(r'[^\w\s]', '', title)
  return ''.join(title.title().split()[:6])

# %%
def title_finder(soup, source):
  # testing default title finder
  title = soup.findAll('h1')

  # if the title is empty, test another title finder
  if len(title) == 0:
    # testing another title finder
    title = soup.findAll('title')

  title = title[0].get_text()
  title = title.replace('\n', '')

  # if the title is not empty, return it
  if len(title) != 0:
    return title

  # another title finder format for CNN articles
  if source == 'cnn':
    title = soup.findAll('h1', {'class': 'headline__text inline-placeholder'})[0].get_text()
    title = title.replace('  ', '')
    title = title.replace('\n', '')

    return title

# %%
def add_text_column(df):
  # adding a column for the text contents
  df['TEXT'] = ''

  for index, row in df.iterrows():
    filename = row['FILENAME']
    text = codecs.open('txt_files/' + filename, "r", encoding='utf8').read()

    df.at[index, 'TEXT'] = text

  return df

# %%
def create_database(urls_df):

  # the new database of science explainers
  database = pd.DataFrame(columns = ['FILENAME', 'TITLE', 'SOURCE', 'DATE PUBLISHED', 'URL'])

  # iterating through each column of the df, which translates to each source
  # of science explainers
  for col in urls_df.columns:

    cur_source = col

    new_folder_name = 'txt_files/' + cur_source
    new_folder_name = new_folder_name.replace(' ', '_')
    # !mkdir $new_folder_name

    # iterating through the rows of the current column of the df, which
    # translates to the article urls from the current source
    for index, row in urls_df[col].items():

      cur_url = row

      # skip empty urls
      if cur_url == '':
        continue

      # gets the website content
      r = requests.get(cur_url)
      soup = BeautifulSoup(r.content, 'html.parser')

      # extracts the title of the article
      title = title_finder(soup, cur_source)

      # edit the title for the filename (title case and only the first 5 words)
      title_cut = title_cleaner(title)

      # creates a new file, writes entire article to it, then saves in the txt_files folder
      filename = cur_source.replace(' ', '_') + '/' + title_cut + '.txt'
      create_txt_file(soup, filename)

      # retrieves the date of publication
      date = all_date_finder(cur_source, soup)

      # adds a row to the science explainer database with the info of this article
      new_row = pd.DataFrame({'FILENAME': filename, 
                              'TITLE': title, 
                              'SOURCE': cur_source, 
                              'DATE PUBLISHED': date,
                              'URL': cur_url}, 
                             index = [0])
      #database = database.append(new_row, ignore_index=True)
      database = pd.concat([database, new_row], ignore_index = True)

  # returns the new database
  return database

# %% [markdown]
# ## Date finder functions

# %%
def basic_date_finder(soup):
  date_bunch = soup.select_one('time')
  date = re.search('(?<= datetime=")(.*?)(=?T)', str(date_bunch)).group(1)
  return date

# %%
def atlantic_date_finder(soup):
  return basic_date_finder(soup)

# %%
def cbc_date_finder(soup):
  return basic_date_finder(soup)

# %%
def cnn_date_finder(soup):
  date_bunch = soup.find('link', {'rel': 'canonical'})
  date = re.search('(?<=cnn\.com\/)(\d\d\d\d\/\d\d\/\d\d)(=?)', str(date_bunch)).group(1)
  date = date.replace('/', '-')
  return date

# %%
def globeandmail_date_finder(soup):
  return basic_date_finder(soup)

# %%
def massivesci_date_finder(soup):
  return basic_date_finder(soup)

# %%
def nationalgeographic_date_finder(soup):
  soup_as_string = str(soup)
  date = re.search('(?<="pbDt":")(.*?)(=?T)', soup_as_string).group(1)
  return date

# %%
def nationalobserver_date_finder(soup):
  soup_as_string = str(soup)
  date = re.search('(?<="datePublished": ")(.*?)(=?T)', soup_as_string).group(1)
  return date

# %%
def npr_date_finder(soup):
  date_bunch = soup.find('link', {'rel': 'canonical'})
  date = re.search('(\d\d\d\d\/\d\d\/\d\d)', str(date_bunch)).group(1)
  date = date.replace('/', '-')
  return date

# %%
def reuters_date_finder(soup):
  date_bunch = soup.find('link', {'rel': 'canonical'})
  date = re.search('(\d\d\d\d-\d\d-\d\d)', str(date_bunch)).group(1)
  return date

# %%
def all_date_finder(source_name, soup):
  # the name of the specific source's date finder function name
  finder_func = source_name.lower().replace(' ', '') + '_date_finder'

  # calls the specific source's date finder function
  return (eval(finder_func)(soup))

# %%
def date_finder_tester(source_name, urls_df):
  # gets the urls from source source_name
  urls = urls_df[source_name]

  # the name of the specific source's date finder function name
  finder_func = source_name.lower().replace(' ', '') + '_date_finder'
  
  # iterates through the url list
  for url in urls:

    # skip empty urls
    if url == '':
      continue

    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')

    # prints the date found
    print(eval(finder_func)(soup))

# %% [markdown]
# # Testing

# %%
### making a copy of the df without the NYT articles, since they're behind a paywall
urls_no_nyt_df = urls_df.drop(columns = ['NYT'])

# %%
urls_no_nyt_df
# Out:
#                                              ATLANTIC  \
# 0   https://www.theatlantic.com/science/archive/20...
# 1   https://www.theatlantic.com/science/archive/20...
# 2   https://www.theatlantic.com/science/archive/20...
# 3   https://www.theatlantic.com/science/archive/20...
# 4   https://www.theatlantic.com/science/archive/20...
# 5   https://www.theatlantic.com/science/archive/20...
# 6   https://www.theatlantic.com/science/archive/20...
# 7   https://www.theatlantic.com/science/archive/20...
# 8   https://www.theatlantic.com/science/archive/20...
# 9   https://www.theatlantic.com/science/archive/20...
# 10  https://www.theatlantic.com/science/archive/20...
# 11  https://www.theatlantic.com/science/archive/20...
# 12  https://www.theatlantic.com/science/archive/20...
# 13  https://www.theatlantic.com/science/archive/20...
# 14  https://www.theatlantic.com/science/archive/20...
# 15  https://www.theatlantic.com/science/archive/20...
# 16  https://www.theatlantic.com/science/archive/20...
# 17  https://www.theatlantic.com/health/archive/202...
# 18  https://www.theatlantic.com/science/archive/20...
# 19
#
#                                                   CBC  \
# 0   https://www.cbc.ca/radio/quirks/dec-3-growling...
# 1   https://www.cbc.ca/radio/quirks/black-holes-je...
# 2   https://www.cbc.ca/radio/quirks/europe-s-juice...
# 3   https://www.cbc.ca/radio/quirks/artificial-int...
# 4   https://www.cbc.ca/radio/quirks/habitable-plan...
# 5   https://www.cbc.ca/radio/quirks/koala-book-dan...
# 6   https://www.cbc.ca/radio/quirks/research-earli...
# 7   https://www.cbc.ca/radio/quirks/feb-25-giraffe...
# 8   https://www.cbc.ca/radio/quirks/feb-18-super-s...
# 9   https://www.cbc.ca/news/science/edna-vacuum-ai...
# 10  https://www.cbc.ca/news/canada/windsor/bird-mi...
# 11  https://www.cbc.ca/news/canada/kitchener-water...
# 12  https://www.cbc.ca/news/canada/british-columbi...
# 13  https://www.cbc.ca/news/canada/british-columbi...
# 14  https://www.cbc.ca/news/canada/newfoundland-la...
# 15  https://www.cbc.ca/news/canada/invasive-turtle...
# 16  https://www.cbc.ca/news/science/what-on-earth-...
# 17  https://www.cbc.ca/news/science/what-on-earth-...
# 18  https://www.cbc.ca/news/science/what-on-earth-...
# 3       2023-04-29  https://www.theatlantic.com/science/archive/20...
# 4       2023-04-23  https://www.theatlantic.com/science/archive/20...
# ..             ...                                                ...
# 168     2023-04-04  https://www.reuters.com/lifestyle/science/stud...
# 169     2023-03-27  https://www.reuters.com/lifestyle/science/intr...
# 170     2023-03-23  https://www.reuters.com/lifestyle/science/scie...
# 171     2023-03-22  https://www.reuters.com/lifestyle/science/lock...
# 172     2023-03-21  https://www.reuters.com/lifestyle/science/seco...
#
# [173 rows x 5 columns]

# %% [markdown]
# # Downloading txt files

# %%
from google.colab import files

# !zip -r txt_files.zip txt_files
files.download("txt_files.zip")
# Out:
#   adding: txt_files/ (stored 0%)
#   adding: txt_files/NATIONAL_OBSERVER/ (stored 0%)
#   adding: txt_files/NATIONAL_OBSERVER/GasolineVersusElectricCarsHeresHow.txt (deflated 62%)
#   adding: txt_files/NATIONAL_OBSERVER/TidepoweredCleanEnergyCouldHelpWest.txt (deflated 54%)
#   adding: txt_files/NATIONAL_OBSERVER/MeatInModerationCanBePart.txt (deflated 58%)
#   adding: txt_files/NATIONAL_OBSERVER/EscootersSilentMenaceOrGreenGodsend.txt (deflated 57%)
#   adding: txt_files/NATIONAL_OBSERVER/ADeepDiveIntoHfcsOne.txt (deflated 62%)
#   adding: txt_files/NATIONAL_OBSERVER/NewfoundlandAndLabradorsOilExplorationPlans.txt (deflated 57%)
#   adding: txt_files/NATIONAL_OBSERVER/BisonOnThisPrairieFarmBring.txt (deflated 51%)
#   adding: txt_files/NATIONAL_OBSERVER/APavedGreenbeltWillKneecapOntarios.txt (deflated 50%)
#   adding: txt_files/NATIONAL_OBSERVER/UncheckedClimateChangePutsCanadasWest.txt (deflated 56%)
#   adding: txt_files/NATIONAL_OBSERVER/MeetTheDogsSniffingStinkyMussels.txt (deflated 53%)
#   adding: txt_files/NATIONAL_OBSERVER/HowLightPollutionIsUpendingThe.txt (deflated 53%)
#   adding: txt_files/NATIONAL_OBSERVER/OneOfCanadasBiggestCarbonSinks.txt (deflated 59%)
#   adding: txt_files/NATIONAL_OBSERVER/HumandrivenClimateChaosFuellingHornOf.txt (deflated 57%)
#   adding: txt_files/NATIONAL_OBSERVER/ExtinctPolynesianSnailsMakeTriumphantReturn.txt (deflated 52%)
#   adding: txt_files/NATIONAL_OBSERVER/DeepseaMiningCouldBeGreenlitIn.txt (deflated 49%)
#   adding: txt_files/NATIONAL_OBSERVER/IsTheNewSalmonOnCanadas.txt (deflated 56%)
#   adding: txt_files/NATIONAL_OBSERVER/AnalysisOfAntiindigenousRacismInHospitals.txt (deflated 59%)
#   adding: txt_files/NATIONAL_OBSERVER/AnishinaabeArtistReinventsTheLoungeChair.txt (deflated 51%)
#   adding: txt_files/NATIONAL_OBSERVER/OverheatedCanadasGasolineEmissionsAreSurging.txt (deflated 63%)
#   adding: txt_files/ATLANTIC/ (stored 0%)
#   adding: txt_files/ATLANTIC/AnimalsAreMigratingToTheGreat.txt (deflated 54%)
#   adding: txt_files/ATLANTIC/TeenBrainsArePerfectlyCapable.txt (deflated 61%)
#   adding: txt_files/NPR/GlobalWarmingCouldBeJuicingBaseball.txt (deflated 55%)
#   adding: txt_files/NPR/WarmingfueledSupercellsWillHitTheSouthern.txt (deflated 59%)
#   adding: txt_files/NPR/SwimmingPoolsAndLavishGardensOf.txt (deflated 54%)
#   adding: txt_files/NPR/ADecoderThatUsesBrainScans.txt (deflated 56%)
#   adding: txt_files/NPR/DeathMetalSingersHaveAVocal.txt (deflated 55%)
#   adding: txt_files/NPR/IsGrayHairReversibleANew.txt (deflated 53%)
#   adding: txt_files/NPR/CovidDuringPregnancyMayAlterBrain.txt (deflated 56%)
#   adding: txt_files/NPR/ThisFloatingOceanGarbageIsHome.txt (deflated 61%)
#   adding: txt_files/NPR/TheresAVolumeWarHappeningIn.txt (deflated 53%)
#   adding: txt_files/NPR/ThisCompanyAdoptedAiHeresWhat.txt (deflated 60%)
#   adding: txt_files/NPR/ThinkYoureTiredThisAnimalGoes.txt (deflated 57%)
#   adding: txt_files/NPR/RenewableEnergyIsHereButHow.txt (deflated 52%)
#   adding: txt_files/NPR/WhereTheresGenderEqualityPeopleTend.txt (deflated 59%)
#   adding: txt_files/NPR/LonelyPetParrotsFindFriendshipThrough.txt (deflated 57%)
#   adding: txt_files/NPR/StudyFindsGunAssaultRatesDoubled.txt (deflated 55%)
#   adding: txt_files/NPR/GiantBlobsOfSeaweedAreHitting.txt (deflated 58%)
#   adding: txt_files/GLOBE_AND_MAIL/ (stored 0%)
#   adding: txt_files/GLOBE_AND_MAIL/ScientistsEnvisionTheSchoolOfCosmic.txt (deflated 55%)
#   adding: txt_files/GLOBE_AND_MAIL/WantToLiveLongerStopFocusing.txt (deflated 58%)
#   adding: txt_files/GLOBE_AND_MAIL/ExcessiveHeatFromClimateChangeIs.txt (deflated 58%)
#   adding: txt_files/GLOBE_AND_MAIL/AtRiskForDiabetesALowcarb.txt (deflated 57%)
#   adding: txt_files/GLOBE_AND_MAIL/LifesciencesResearchFacilitiesSproutingInVancouvers.txt (deflated 56%)
#   adding: txt_files/GLOBE_AND_MAIL/CanExerciseHelpBrainHealthWhat.txt (deflated 54%)
#   adding: txt_files/GLOBE_AND_MAIL/WantAHealthyGutNewResearch.txt (deflated 54%)
#   adding: txt_files/GLOBE_AND_MAIL/FusionBreakthroughCouldBeClimateEnergy.txt (deflated 63%)
#   adding: txt_files/GLOBE_AND_MAIL/AntiinflammatoryDietImprovesFemaleFertilityStudy.txt (deflated 55%)
#   adding: txt_files/GLOBE_AND_MAIL/DaylightSavingsTimeSleepTipsIf.txt (deflated 54%)
#   adding: txt_files/GLOBE_AND_MAIL/MapOfDarkMatterShedsNew.txt (deflated 54%)
#   adding: txt_files/GLOBE_AND_MAIL/TheScienceOfMakingAndKeeping.txt (deflated 56%)
#   adding: txt_files/GLOBE_AND_MAIL/FillingUpOnFlavonolsMaySlow.txt (deflated 57%)
#   adding: txt_files/GLOBE_AND_MAIL/FightToCurbFoodWasteIncreasingly.txt (deflated 52%)
